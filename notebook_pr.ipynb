# %%
import pandas as pd
import numpy as np
import psycopg2
import mysql.connector
from datetime import date, datetime, timedelta
aws_credentials = { "key": "AKIAYAFNZI7E56ZYMHML", "secret": "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" }

# %%
def extract_products():
    name_cabeceras=["product_id","product_category_id","product_name","product_description","product_price","product_image"]
    df_products = pd.read_csv("s3://datapathcchb/products", storage_options=aws_credentials, sep="|", header=None, names=name_cabeceras)
    return df_products

def extract_departments():
    name_cabe_depart=["departament_id","departament_name"]
    df_departments = pd.read_csv("s3://datapathcchb/departments", storage_options=aws_credentials, sep="|", header=None, names=name_cabe_depart)
    return df_departments

# %%
dff_products=extract_products()
dff_departments=extract_departments()

# %%
dff_products
# Out:
#       product_id  product_category_id  \
# 0              1                    2
# 1              2                    2
# 2              3                    2
# 3              4                    2
# 4              5                    2
# ...          ...                  ...
# 1340        1341                   59
# 1341        1342                   59
# 1342        1343                   59
# 1343        1344                   59
# 1344        1345                   59
#
#                                        product_name  product_description  \
# 0     Quest Q64 10 FT. x 10 FT. Slant Leg Instant U                  NaN
# 1     Under Armour Men's Highlight MC Football Clea                  NaN
# 2     Under Armour Men's Renegade D Mid Football Cl                  NaN
# 3     Under Armour Men's Renegade D Mid Football Cl                  NaN
# 4     Riddell Youth Revolution Speed Custom Footbal                  NaN
# ...

# %%
dff_products.dtypes
# Out:
# product_id               int64
# product_category_id      int64
# product_name            object
# product_description    float64
# product_price          float64
# product_image           object
# dtype: object

# %%
dff_departments
# Out:
#    departament_id departament_name
# 0               2          Fitness
# 1               3         Footwear
# 2               4          Apparel
# 3               5             Golf
# 4               6         Outdoors
# 5               7         Fan Shop

# %%
dff_departments.dtypes
# Out:
# departament_id       int64
# departament_name    object
# dtype: object

# %%
import pymysql
class Database:
    def connect(self):

        return pymysql.connect(host="localhost", user="root", password="123456", database="datapath", charset='utf8mb4')

    def read(self, id):
        con = Database.connect(self)
        cursor = con.cursor(pymysql.cursors.DictCursor)

        try:
            if id == None:
                cursor.execute("SELECT * FROM phone_book order by name asc")
            else:
                cursor.execute(
                    "SELECT * FROM phone_book where id = %s order by name asc", (id,))

            return cursor.fetchall()
        except:
            return ()
        finally:
            con.close()

# %%
def conexionbd(flagbd):

    if flagbd =='mysql':
        mydb = mysql.connector.connect(host="localhost",user="root",password="toor",database="datapath")
        conn=mydb

    if flagbd =='possql':
        cad = psycopg2.connect(database = "datapath", user = "postgres", password = "toor", host = "localhost", port = "5432")
        conn=cad

    return conn

# %%
def extract_table_query(connection,query):
    df=pd.read_sql(query, con=connection)
    return df

# %%
cadena_mysql=conexionbd("mysql")
cadena_possql=conexionbd("possql")

sql_order_items="select * from order_items"
sql_orders="select * from orders2"
sql_customer="select * from customer"
sql_categories="select * from categories"

order_items=extract_table_query(cadena_mysql,sql_order_items)
orders=extract_table_query(cadena_mysql,sql_orders)
customer=extract_table_query(cadena_possql,sql_customer)
categories=extract_table_query(cadena_possql,sql_categories)
# Out:
# c:\Users\CCHAVARRY\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# c:\Users\CCHAVARRY\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# c:\Users\CCHAVARRY\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# ...

# %%
order_items
# Out:
#         order_item_id  order_item_order_id  order_item_product_id  \
# 0                   1                    1                    957
# 1                   2                    2                   1073
# 2                   3                    2                    502
# 3                   4                    2                    403
# 4                   5                    4                    897
# ...               ...                  ...                    ...
# 172193         172194                68881                    403
# 172194         172195                68882                    365
# 172195         172196                68882                    502
# 172196         172197                68883                    208
# 172197         172198                68883                    502
#
#         order_item_quantity  order_item_subtotal  order_item_productprice
# 0                         1               299.98                   299.98
# ...

# %%
orders
# Out:
#        order_id  order_date  order_customer_id    order_staturs
# 0             1  2021-07-25              11599           CLOSED
# 1             2  2021-07-25                256  PENDING_PAYMENT
# 2             3  2021-07-25              12111         COMPLETE
# 3             4  2021-07-25               8827           CLOSED
# 4             5  2021-07-25              11318         COMPLETE
# ...         ...         ...                ...              ...
# 68878     68879  2022-07-09                778         COMPLETE
# 68879     68880  2022-07-13               1117         COMPLETE
# 68880     68881  2022-07-19               2518  PENDING_PAYMENT
# 68881     68882  2022-07-22              10000          ON_HOLD
# 68882     68883  2022-07-23               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
customer
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_state  \
# 0             XXXXXXXXX          6303 Heather Plaza    Brownsville
# ...

# %%
categories
# Out:
#     category_id  category_departament_id         category_name
# 0             1                        2              Football
# 1             2                        2                Soccer
# 2             3                        2   Baseball & Softball
# 3             4                        2            Basketball
# 4             5                        2              Lacrosse
# 5             6                        2      Tennis & Racquet
# 6             7                        2                Hockey
# 7             8                        2           More Sports
# 8             9                        3      Cardio Equipment
# 9            10                        3     Strength Training
# 10           11                        3   Fitness Accessories
# 11           12                        3          Boxing & MMA
# 12           13                        3           Electronics
# 13           14                        3        Yoga & Pilates
# ...

# %%
order_items
orders.head()
# Out:
#    order_id  order_date  order_customer_id    order_staturs
# 0         1  2021-07-25              11599           CLOSED
# 1         2  2021-07-25                256  PENDING_PAYMENT
# 2         3  2021-07-25              12111         COMPLETE
# 3         4  2021-07-25               8827           CLOSED
# 4         5  2021-07-25              11318         COMPLETE

# %%
hoy=date.today()
hoy1=hoy.replace(day=1)
fnew=datetime(hoy1.year,hoy1.month,hoy1.day)
fnew2=date(hoy1.year,hoy1.month,hoy1.day)

# %%
print(hoy)
print(hoy1)
print (fnew)
print (fnew2)

type(hoy)
type(hoy1)
type(fnew)
type(fnew2)
# Out:
# 2022-06-28
# 2022-06-01
# 2022-06-01 00:00:00
# 2022-06-01
# datetime.date

# %% [markdown]
# Obtener los 6 meses

# %%
from datetime import datetime,timedelta
from dateutil.relativedelta import relativedelta

# %%
    hoy=date.today()
    fecha=hoy.replace(day=1)
    month = relativedelta(months=6)
    month1 = relativedelta(months=1)
    hoy_menos_meses = fecha - month
    hoy_menos_uno = fecha - month1
    periodo_inicio=hoy_menos_meses.year*100+hoy_menos_meses.month
    periodo_fin=hoy_menos_meses.year*100+hoy_menos_uno.month
    print(month)
    print (hoy_menos_meses)
    print (fecha)
    print(periodo_inicio)
    print(periodo_fin)
# Out:
# relativedelta(months=+6)
# 2021-12-01
# 2022-06-01
# 202112
# 202105

# %%
orders["order_date"].max()
orders["order_date"].min()
# Out:
# Timestamp('2013-07-25 00:00:00')

# %%
orders2=orders[ (orders["order_date"] >=hoy_menos_meses) & (orders["order_date"] < fecha) & (orders["order_staturs"] == 'COMPLETE') ]
orders2.count()
# Out:
# order_id             11431
# order_date           11431
# order_customer_id    11431
# order_staturs        11431
# dtype: int64

# %%
items_group=order_items[["order_item_order_id","order_item_subtotal"]]\
.groupby("order_item_order_id", as_index=False)\
.agg({"order_item_subtotal": "sum"})

items_group.count()
items_group
# Out:
#        order_item_order_id  order_item_subtotal
# 0                        1               299.98
# 1                        2               579.98
# 2                        4               699.85
# 3                        5              1129.86
# 4                        7               579.92
# ...                    ...                  ...
# 57426                68879              1259.97
# 57427                68880               999.77
# 57428                68881               129.99
# 57429                68882               109.99
# 57430                68883              2149.99
#
# [57431 rows x 2 columns]

# %%
order_join_items=pd.merge(orders2,items_group , how='inner',left_on='order_id',right_on='order_item_order_id')

order_join_items
# Out:
#       order_id  order_date  order_customer_id order_staturs  \
# 0        20919  2021-12-01                383      COMPLETE
# 1        20923  2021-12-01              10118      COMPLETE
# 2        20926  2021-12-01              12321      COMPLETE
# 3        20928  2021-12-01               1516      COMPLETE
# 4        20935  2021-12-01              12301      COMPLETE
# ...        ...         ...                ...           ...
# 9445     68837  2022-05-07               1223      COMPLETE
# 9446     68839  2022-05-10              10090      COMPLETE
# 9447     68844  2022-05-17                443      COMPLETE
# 9448     68845  2022-05-18               6584      COMPLETE
# 9449     68847  2022-05-21               2543      COMPLETE
#
#       order_item_order_id  order_item_subtotal
# 0                   20919               289.95
# 1                   20923               699.93
# 2                   20926               419.90
# 3                   20928               973.94
# ...

# %%
order_item_group=order_join_items[["order_customer_id","order_item_subtotal"]]\
.groupby("order_customer_id", as_index=False)\
.agg({"order_item_subtotal": "sum"})

order_item_group=order_item_group.assign(per_ini=periodo_inicio)
order_item_group=order_item_group.assign(per_fin=periodo_fin)

# %%
order_item_group
# Out:
#       order_customer_id  order_item_subtotal  per_ini  per_fin
# 0                     1               499.95   202112   202105
# 1                     2               549.97   202112   202105
# 2                     3              1607.90   202112   202105
# 3                     4               519.93   202112   202105
# 4                     5               129.99   202112   202105
# ...                 ...                  ...      ...      ...
# 6703              12425              1357.88   202112   202105
# 6704              12426               199.99   202112   202105
# 6705              12427              1211.88   202112   202105
# 6706              12432              1244.77   202112   202105
# 6707              12434               579.94   202112   202105
#
# [6708 rows x 4 columns]

# %%
order_item_group['cod_category'] = \
np.where((order_item_group['order_item_subtotal']>0) & (order_item_group['order_item_subtotal']<=950), 'A',
np.where((order_item_group['order_item_subtotal']>950) & (order_item_group['order_item_subtotal']<=1500), 'B',
np.where((order_item_group['order_item_subtotal']>1500) & (order_item_group['order_item_subtotal']<=2500), 'C', 
np.where((order_item_group['order_item_subtotal']>2500) & (order_item_group['order_item_subtotal']<=3500), 'D',
np.where((order_item_group['order_item_subtotal']>3500) & (order_item_group['order_item_subtotal']<=5000), 'E',
np.where((order_item_group['order_item_subtotal']>5000), 'E','-'
))))))

# %%
order_item_group
# Out:
#       order_customer_id  order_item_subtotal  per_ini  per_fin cod_category
# 0                     1               499.95   202112   202105            A
# 1                     2               549.97   202112   202105            A
# 2                     3              1607.90   202112   202105            C
# 3                     4               519.93   202112   202105            A
# 4                     5               129.99   202112   202105            A
# ...                 ...                  ...      ...      ...          ...
# 6703              12425              1357.88   202112   202105            B
# 6704              12426               199.99   202112   202105            A
# 6705              12427              1211.88   202112   202105            B
# 6706              12432              1244.77   202112   202105            B
# 6707              12434               579.94   202112   202105            A
#
# [6708 rows x 5 columns]
